# %%
import pandas as pd

from pyc.pyc_model import *
from pyc.pyc_pred import *

# 3 inputs from user 1-> train 2-> test 3-> target column

df=pd.read_csv('C:\\Users\\Praful\\Desktop\\project\\evalml\\webapp\\House_pred_train.csv')
df.drop(['Exterior1st_ImStucc', 'Exterior1st_Stone', 'Exterior2nd_Other', 'GarageQual_Fa'],axis=1,inplace=True)

test = pd.read_csv('C:\\Users\\Praful\\Desktop\\project\\evalml\\webapp\\House_pred_test.csv')

all_model = ModelTraining.modeltraining(df,'SalePrice')

#df1 = pd.DataFrame(all_model)

#df1.to_csv('all_model.csv')



all_model
# Out:
# <style type="text/css">
# #T_871e9 th {
#   text-align: left;
# }
# ...

# %%
obj1 = ModelPrediction()

# %%
gbr = obj1.createmodel('et')
# Out:
# <style type="text/css">
# #T_20888_row10_col0, #T_20888_row10_col1, #T_20888_row10_col2, #T_20888_row10_col3, #T_20888_row10_col4, #T_20888_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_20888">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20888_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_20888_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_20888_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_20888_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_20888_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_20888_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
obj1.tunemodel(gbr)
# Out:
# <style type="text/css">
# #T_67206_row10_col0, #T_67206_row10_col1, #T_67206_row10_col2, #T_67206_row10_col3, #T_67206_row10_col4, #T_67206_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_67206">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67206_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_67206_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_67206_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_67206_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_67206_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_67206_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
obj1.evalmodel(gbr)
# Out:
# <style type="text/css">
# #T_bd867_row10_col0, #T_bd867_row10_col1, #T_bd867_row10_col2, #T_bd867_row10_col3, #T_bd867_row10_col4, #T_bd867_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bd867">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd867_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bd867_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bd867_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bd867_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bd867_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bd867_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
test = pd.read_csv('C:\\Users\\Praful\\Desktop\\project\\evalml\\webapp\\House_pred_test.csv')

# %%
y_pred = obj1.modelprediction(gbr,test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 y_pred = obj1.modelprediction(gbr,test)
#
# TypeError: modelprediction() takes 2 positional arguments but 3 were given

# %%
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y_pred
#
# NameError: name 'y_pred' is not defined

# %%
y_pred.iloc[75]
# Out:
# Unnamed: 0                   75.000000
# MSSubClass                   50.000000
# LotFrontage                  68.000000
# LotArea                    8239.000000
# OverallQual                   5.000000
#                              ...
# SaleCondition_Alloca          0.000000
# SaleCondition_Family          0.000000
# SaleCondition_Normal          1.000000
# SaleCondition_Partial         0.000000
# Label                    109561.782761
# Name: 75, Length: 178, dtype: float64

# %%
import requests
import pandas as pd

def call_flask_api():
    data = {"input": "example input"}
    response = requests.post('http://localhost:5000/predict', json=data)
    return pd.DataFrame(response.json())

df = call_flask_api()
st.dataframe(df)
